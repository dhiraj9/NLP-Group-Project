# %%
import pandas as pd
import datasets
from transformers import RobertaTokenizerFast, RobertaForSequenceClassification,Trainer, TrainingArguments, PretrainedConfig
import torch.nn as nn
import torch
from torch.utils.data import Dataset, DataLoader
import numpy as np
from sklearn.metrics import accuracy_score, precision_recall_fscore_support
import sklearn.metrics as metric
from tqdm import tqdm
import wandb
import os

# %%
path  = '/home/csgrad/smaranas/STDA/'

# %%
# load model and tokenizer and define length of the text sequence
model = RobertaForSequenceClassification.from_pretrained('roberta-base', num_labels=11)
tokenizer = RobertaTokenizerFast.from_pretrained('roberta-base', max_length = 512)
# Out:
# Some weights of the model checkpoint at roberta-base were not used when initializing RobertaForSequenceClassification: ['lm_head.layer_norm.weight', 'roberta.pooler.dense.weight', 'lm_head.layer_norm.bias', 'lm_head.dense.bias', 'lm_head.dense.weight', 'lm_head.decoder.weight', 'lm_head.bias', 'roberta.pooler.dense.bias']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at roberta-base and are newly initialized: ['classifier.dense.weight', 'classifier.dense.bias', 'classifier.out_proj.weight', 'classifier.out_proj.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
train_data = datasets.load_dataset('csv', data_files='p3_train.csv', split='train')
test_data = datasets.load_dataset('csv', data_files='p3_test.csv', split='train')
# Out:
# Using custom data configuration default-903b86b0d8c77dba
# Reusing dataset csv (/home/csgrad/smaranas/.cache/huggingface/datasets/csv/default-903b86b0d8c77dba/0.0.0/652c3096f041ee27b04d2232d41f10547a8fecda3e284a79a0ec4053c916ef7a)
# Using custom data configuration default-7066673e9c105372
# Reusing dataset csv (/home/csgrad/smaranas/.cache/huggingface/datasets/csv/default-7066673e9c105372/0.0.0/652c3096f041ee27b04d2232d41f10547a8fecda3e284a79a0ec4053c916ef7a)

# %%
# define a function that will tokenize the model, and will return the relevant inputs for the model
def tokenization(batched_text):
  return tokenizer(batched_text['text'], padding = True, truncation=True)


train_data = train_data.map(tokenization, batched = True, batch_size = len(train_data))
test_data = test_data.map(tokenization, batched = True, batch_size = len(test_data))
# Out:
# Loading cached processed dataset at /home/csgrad/smaranas/.cache/huggingface/datasets/csv/default-903b86b0d8c77dba/0.0.0/652c3096f041ee27b04d2232d41f10547a8fecda3e284a79a0ec4053c916ef7a/cache-e16fc8fa15282362.arrow
# Loading cached processed dataset at /home/csgrad/smaranas/.cache/huggingface/datasets/csv/default-7066673e9c105372/0.0.0/652c3096f041ee27b04d2232d41f10547a8fecda3e284a79a0ec4053c916ef7a/cache-173a221bfce50882.arrow

# %%
train_data.set_format('torch', columns=['input_ids', 'attention_mask', 'label'])
test_data.set_format('torch', columns=['input_ids', 'attention_mask', 'label'])

# %%
# define accuracy metrics
def compute_metrics(pred):
    labels = pred.label_ids
    preds = pred.predictions.argmax(-1)
    precision, recall, f1, _ = precision_recall_fscore_support(labels, preds, average='macro')
    acc = accuracy_score(labels, preds)
    # fpr, tpr, threshold = metric.roc_curve(labels, preds, pos_label=1)
    # # calibration_loss = metric.brier_score_loss(labels, )

    # fnr = 1 - tpr
    # eer_threshold = threshold[np.nanargmin(np.absolute((fnr - fpr)))]
    # EER = fpr[np.nanargmin(np.absolute((fnr - fpr)))]
    # EER1 = fnr[np.nanargmin(np.absolute((fnr - fpr)))]
    # if EER == EER1:
    #   print('EER sanity check passed')
    #   print('fpr : ', fpr)
    #   print('tpr : ', tpr)
    #   print('threshold : ', threshold)
    #   print('EER : ', EER)

    return {
        'accuracy': acc,
        'f1': f1,
        'precision': precision,
        'recall': recall,
        # 'fpr': fpr, 
        # 'tpr': tpr, 
        # 'threshold': threshold,
        # 'EER': EER,
        
    }

# %%
#  define the training arguments
training_args = TrainingArguments(
    output_dir = path,
    num_train_epochs=30,
    per_device_train_batch_size = 3,
    gradient_accumulation_steps = 16,    
    per_device_eval_batch_size= 8,
    evaluation_strategy = "epoch",
    disable_tqdm = False, 
    save_strategy = "epoch",
    load_best_model_at_end=True,
    warmup_steps=500,
    weight_decay=0.01,
    logging_steps = 8,
    # fp16 = True,
    logging_dir=path+'/logs',
    dataloader_num_workers = 0,
    run_name = 'roberta-classification_titan'
)

# %%
# instantiate the trainer class and check for available devices
trainer = Trainer(
    model=model,
    args=training_args,
    compute_metrics=compute_metrics,
    train_dataset=train_data,
    eval_dataset=test_data
)
device = 'cuda' if torch.cuda.is_available() else 'cpu'
device
# Out:
# 'cuda'

# %%
trainer.train()
# Out:
# The following columns in the training set  don't have a corresponding argument in `RobertaForSequenceClassification.forward` and have been ignored: Unnamed: 0, text. If Unnamed: 0, text are not expected by `RobertaForSequenceClassification.forward`,  you can safely ignore this message.
# /home/csgrad/smaranas/.local/lib/python3.6/site-packages/transformers/optimization.py:309: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# ***** Running training *****
#   Num examples = 9486
#   Num Epochs = 30
#   Instantaneous batch size per device = 3
#   Total train batch size (w. parallel, distributed & accumulation) = 192
#   Gradient Accumulation steps = 16
#   Total optimization steps = 1470
# Automatic Weights & Biases logging enabled, to disable set os.environ["WANDB_DISABLED"] = "true"
# wandb: Currently logged in as: psmarana. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.14.0
# Run data is saved locally in <code>/home/csgrad/smaranas/STDA/wandb/run-20230401_115333-ahhvr7h9</code>
# Syncing run <strong><a href='https://wandb.ai/psmarana/huggingface/runs/ahhvr7h9' target="_blank">roberta-classification_titan</a></strong> to <a href='https://wandb.ai/psmarana/huggingface' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/psmarana/huggingface' target="_blank">https://wandb.ai/psmarana/huggingface</a>
#  View run at <a href='https://wandb.ai/psmarana/huggingface/runs/ahhvr7h9' target="_blank">https://wandb.ai/psmarana/huggingface/runs/ahhvr7h9</a>
# /home/csgrad/smaranas/.local/lib/python3.6/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
#     <div>
#
#       <progress value='1470' max='1470' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1470/1470 2:16:53, Epoch 29/30]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#       <th>F1</th>
#       <th>Precision</th>
#       <th>Recall</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.289800</td>
#       <td>2.186842</td>
#       <td>0.287099</td>
#       <td>0.220402</td>
#       <td>0.356885</td>
#       <td>0.296571</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.355000</td>
#       <td>1.166198</td>
#       <td>0.654722</td>
#       <td>0.627497</td>
#       <td>0.648720</td>
#       <td>0.655857</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.820100</td>
#       <td>0.696295</td>
#       <td>0.765599</td>
#       <td>0.764098</td>
#       <td>0.776460</td>
#       <td>0.767222</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.615300</td>
#       <td>0.593255</td>
#       <td>0.787099</td>
#       <td>0.786528</td>
#       <td>0.795460</td>
#       <td>0.789228</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.520700</td>
#       <td>0.536342</td>
#       <td>0.801855</td>
#       <td>0.801658</td>
#       <td>0.811777</td>
#       <td>0.803956</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.468900</td>
#       <td>0.528933</td>
#       <td>0.806071</td>
#       <td>0.799916</td>
#       <td>0.832636</td>
#       <td>0.806804</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.407500</td>
#       <td>0.424498</td>
#       <td>0.844013</td>
#       <td>0.846220</td>
#       <td>0.850551</td>
#       <td>0.847066</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.387600</td>
#       <td>0.457632</td>
#       <td>0.837268</td>
#       <td>0.839441</td>
#       <td>0.849426</td>
#       <td>0.839569</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.218500</td>
#       <td>0.537550</td>
#       <td>0.824621</td>
#       <td>0.822398</td>
#       <td>0.847920</td>
#       <td>0.828028</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.209700</td>
#       <td>0.506270</td>
#       <td>0.833474</td>
#       <td>0.832039</td>
#       <td>0.858325</td>
#       <td>0.837568</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.227600</td>
#       <td>0.659687</td>
#       <td>0.816189</td>
#       <td>0.815709</td>
#       <td>0.842292</td>
#       <td>0.819587</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.123300</td>
#       <td>0.551709</td>
#       <td>0.852867</td>
#       <td>0.853485</td>
#       <td>0.858707</td>
#       <td>0.854334</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.090500</td>
#       <td>0.559344</td>
#       <td>0.854975</td>
#       <td>0.858829</td>
#       <td>0.870259</td>
#       <td>0.858446</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.134500</td>
#       <td>0.558760</td>
#       <td>0.853710</td>
#       <td>0.857112</td>
#       <td>0.868779</td>
#       <td>0.857630</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.078300</td>
#       <td>0.522413</td>
#       <td>0.869309</td>
#       <td>0.871853</td>
#       <td>0.874690</td>
#       <td>0.871951</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.051700</td>
#       <td>0.664865</td>
#       <td>0.849494</td>
#       <td>0.849879</td>
#       <td>0.858540</td>
#       <td>0.851720</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.032300</td>
#       <td>0.696518</td>
#       <td>0.859612</td>
#       <td>0.862103</td>
#       <td>0.871680</td>
#       <td>0.863486</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.025500</td>
#       <td>0.643400</td>
#       <td>0.863406</td>
#       <td>0.865082</td>
#       <td>0.868850</td>
#       <td>0.865399</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.036700</td>
#       <td>0.826523</td>
#       <td>0.837690</td>
#       <td>0.841903</td>
#       <td>0.867023</td>
#       <td>0.841621</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.024200</td>
#       <td>0.672140</td>
#       <td>0.870152</td>
#       <td>0.873340</td>
#       <td>0.878355</td>
#       <td>0.874128</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.023400</td>
#       <td>0.749824</td>
#       <td>0.856239</td>
#       <td>0.857825</td>
#       <td>0.870065</td>
#       <td>0.858510</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>0.018200</td>
#       <td>0.770781</td>
#       <td>0.868465</td>
#       <td>0.872748</td>
#       <td>0.881134</td>
#       <td>0.871986</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>0.009500</td>
#       <td>0.728389</td>
#       <td>0.872681</td>
#       <td>0.875060</td>
#       <td>0.881235</td>
#       <td>0.874497</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>0.006300</td>
#       <td>0.822151</td>
#       <td>0.859612</td>
#       <td>0.861993</td>
#       <td>0.871396</td>
#       <td>0.863914</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>0.012900</td>
#       <td>0.762331</td>
#       <td>0.873103</td>
#       <td>0.875928</td>
#       <td>0.881466</td>
#       <td>0.877331</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>0.004200</td>
#       <td>0.789314</td>
#       <td>0.872260</td>
#       <td>0.875731</td>
#       <td>0.883078</td>
#       <td>0.876417</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>0.002100</td>
#       <td>0.804961</td>
#       <td>0.869309</td>
#       <td>0.872247</td>
#       <td>0.879808</td>
#       <td>0.873857</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>0.001300</td>
#       <td>0.895249</td>
#       <td>0.861720</td>
#       <td>0.864369</td>
#       <td>0.876884</td>
#       <td>0.866245</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>0.001200</td>
#       <td>0.787886</td>
#       <td>0.876476</td>
#       <td>0.879786</td>
#       <td>0.884091</td>
#       <td>0.880618</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>0.001300</td>
#       <td>0.781676</td>
#       <td>0.877319</td>
#       <td>0.880658</td>
#       <td>0.884335</td>
#       <td>0.881229</td>
#     </tr>
#   </tbody>
# </table><p>
# The following columns in the evaluation set  don't have a corresponding argument in `RobertaForSequenceClassification.forward` and have been ignored: Unnamed: 0, text. If Unnamed: 0, text are not expected by `RobertaForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 2372
#   Batch size = 8
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# Saving model checkpoint to /home/csgrad/smaranas/STDA/checkpoint-49
# Configuration saved in /home/csgrad/smaranas/STDA/checkpoint-49/config.json
# Model weights saved in /home/csgrad/smaranas/STDA/checkpoint-49/pytorch_model.bin
# /home/csgrad/smaranas/.local/lib/python3.6/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set  don't have a corresponding argument in `RobertaForSequenceClassification.forward` and have been ignored: Unnamed: 0, text. If Unnamed: 0, text are not expected by `RobertaForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 2372
#   Batch size = 8
# Saving model checkpoint to /home/csgrad/smaranas/STDA/checkpoint-98
# Configuration saved in /home/csgrad/smaranas/STDA/checkpoint-98/config.json
# Model weights saved in /home/csgrad/smaranas/STDA/checkpoint-98/pytorch_model.bin
# /home/csgrad/smaranas/.local/lib/python3.6/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set  don't have a corresponding argument in `RobertaForSequenceClassification.forward` and have been ignored: Unnamed: 0, text. If Unnamed: 0, text are not expected by `RobertaForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 2372
#   Batch size = 8
# Saving model checkpoint to /home/csgrad/smaranas/STDA/checkpoint-147
# Configuration saved in /home/csgrad/smaranas/STDA/checkpoint-147/config.json
# Model weights saved in /home/csgrad/smaranas/STDA/checkpoint-147/pytorch_model.bin
# /home/csgrad/smaranas/.local/lib/python3.6/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set  don't have a corresponding argument in `RobertaForSequenceClassification.forward` and have been ignored: Unnamed: 0, text. If Unnamed: 0, text are not expected by `RobertaForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 2372
#   Batch size = 8
# Saving model checkpoint to /home/csgrad/smaranas/STDA/checkpoint-196
# Configuration saved in /home/csgrad/smaranas/STDA/checkpoint-196/config.json
# Model weights saved in /home/csgrad/smaranas/STDA/checkpoint-196/pytorch_model.bin
# /home/csgrad/smaranas/.local/lib/python3.6/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set  don't have a corresponding argument in `RobertaForSequenceClassification.forward` and have been ignored: Unnamed: 0, text. If Unnamed: 0, text are not expected by `RobertaForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 2372
#   Batch size = 8
# Saving model checkpoint to /home/csgrad/smaranas/STDA/checkpoint-245
# Configuration saved in /home/csgrad/smaranas/STDA/checkpoint-245/config.json
# Model weights saved in /home/csgrad/smaranas/STDA/checkpoint-245/pytorch_model.bin
# /home/csgrad/smaranas/.local/lib/python3.6/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set  don't have a corresponding argument in `RobertaForSequenceClassification.forward` and have been ignored: Unnamed: 0, text. If Unnamed: 0, text are not expected by `RobertaForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 2372
#   Batch size = 8
# Saving model checkpoint to /home/csgrad/smaranas/STDA/checkpoint-294
# Configuration saved in /home/csgrad/smaranas/STDA/checkpoint-294/config.json
# Model weights saved in /home/csgrad/smaranas/STDA/checkpoint-294/pytorch_model.bin
# /home/csgrad/smaranas/.local/lib/python3.6/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set  don't have a corresponding argument in `RobertaForSequenceClassification.forward` and have been ignored: Unnamed: 0, text. If Unnamed: 0, text are not expected by `RobertaForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 2372
#   Batch size = 8
# Saving model checkpoint to /home/csgrad/smaranas/STDA/checkpoint-343
# Configuration saved in /home/csgrad/smaranas/STDA/checkpoint-343/config.json
# Model weights saved in /home/csgrad/smaranas/STDA/checkpoint-343/pytorch_model.bin
# /home/csgrad/smaranas/.local/lib/python3.6/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set  don't have a corresponding argument in `RobertaForSequenceClassification.forward` and have been ignored: Unnamed: 0, text. If Unnamed: 0, text are not expected by `RobertaForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 2372
#   Batch size = 8
# Saving model checkpoint to /home/csgrad/smaranas/STDA/checkpoint-392
# Configuration saved in /home/csgrad/smaranas/STDA/checkpoint-392/config.json
# Model weights saved in /home/csgrad/smaranas/STDA/checkpoint-392/pytorch_model.bin
# /home/csgrad/smaranas/.local/lib/python3.6/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set  don't have a corresponding argument in `RobertaForSequenceClassification.forward` and have been ignored: Unnamed: 0, text. If Unnamed: 0, text are not expected by `RobertaForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 2372
#   Batch size = 8
# Saving model checkpoint to /home/csgrad/smaranas/STDA/checkpoint-441
# Configuration saved in /home/csgrad/smaranas/STDA/checkpoint-441/config.json
# Model weights saved in /home/csgrad/smaranas/STDA/checkpoint-441/pytorch_model.bin
# /home/csgrad/smaranas/.local/lib/python3.6/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set  don't have a corresponding argument in `RobertaForSequenceClassification.forward` and have been ignored: Unnamed: 0, text. If Unnamed: 0, text are not expected by `RobertaForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 2372
#   Batch size = 8
# Saving model checkpoint to /home/csgrad/smaranas/STDA/checkpoint-490
# Configuration saved in /home/csgrad/smaranas/STDA/checkpoint-490/config.json
# Model weights saved in /home/csgrad/smaranas/STDA/checkpoint-490/pytorch_model.bin
# /home/csgrad/smaranas/.local/lib/python3.6/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set  don't have a corresponding argument in `RobertaForSequenceClassification.forward` and have been ignored: Unnamed: 0, text. If Unnamed: 0, text are not expected by `RobertaForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 2372
#   Batch size = 8
# Saving model checkpoint to /home/csgrad/smaranas/STDA/checkpoint-539
# Configuration saved in /home/csgrad/smaranas/STDA/checkpoint-539/config.json
# Model weights saved in /home/csgrad/smaranas/STDA/checkpoint-539/pytorch_model.bin
# /home/csgrad/smaranas/.local/lib/python3.6/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set  don't have a corresponding argument in `RobertaForSequenceClassification.forward` and have been ignored: Unnamed: 0, text. If Unnamed: 0, text are not expected by `RobertaForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 2372
#   Batch size = 8
# Saving model checkpoint to /home/csgrad/smaranas/STDA/checkpoint-588
# Configuration saved in /home/csgrad/smaranas/STDA/checkpoint-588/config.json
# Model weights saved in /home/csgrad/smaranas/STDA/checkpoint-588/pytorch_model.bin
# /home/csgrad/smaranas/.local/lib/python3.6/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set  don't have a corresponding argument in `RobertaForSequenceClassification.forward` and have been ignored: Unnamed: 0, text. If Unnamed: 0, text are not expected by `RobertaForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 2372
#   Batch size = 8
# Saving model checkpoint to /home/csgrad/smaranas/STDA/checkpoint-637
# Configuration saved in /home/csgrad/smaranas/STDA/checkpoint-637/config.json
# Model weights saved in /home/csgrad/smaranas/STDA/checkpoint-637/pytorch_model.bin
# /home/csgrad/smaranas/.local/lib/python3.6/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set  don't have a corresponding argument in `RobertaForSequenceClassification.forward` and have been ignored: Unnamed: 0, text. If Unnamed: 0, text are not expected by `RobertaForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 2372
#   Batch size = 8
# Saving model checkpoint to /home/csgrad/smaranas/STDA/checkpoint-686
# Configuration saved in /home/csgrad/smaranas/STDA/checkpoint-686/config.json
# Model weights saved in /home/csgrad/smaranas/STDA/checkpoint-686/pytorch_model.bin
# /home/csgrad/smaranas/.local/lib/python3.6/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set  don't have a corresponding argument in `RobertaForSequenceClassification.forward` and have been ignored: Unnamed: 0, text. If Unnamed: 0, text are not expected by `RobertaForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 2372
#   Batch size = 8
# Saving model checkpoint to /home/csgrad/smaranas/STDA/checkpoint-735
# Configuration saved in /home/csgrad/smaranas/STDA/checkpoint-735/config.json
# Model weights saved in /home/csgrad/smaranas/STDA/checkpoint-735/pytorch_model.bin
# /home/csgrad/smaranas/.local/lib/python3.6/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set  don't have a corresponding argument in `RobertaForSequenceClassification.forward` and have been ignored: Unnamed: 0, text. If Unnamed: 0, text are not expected by `RobertaForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 2372
#   Batch size = 8
# Saving model checkpoint to /home/csgrad/smaranas/STDA/checkpoint-784
# Configuration saved in /home/csgrad/smaranas/STDA/checkpoint-784/config.json
# Model weights saved in /home/csgrad/smaranas/STDA/checkpoint-784/pytorch_model.bin
# /home/csgrad/smaranas/.local/lib/python3.6/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set  don't have a corresponding argument in `RobertaForSequenceClassification.forward` and have been ignored: Unnamed: 0, text. If Unnamed: 0, text are not expected by `RobertaForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 2372
#   Batch size = 8
# Saving model checkpoint to /home/csgrad/smaranas/STDA/checkpoint-833
# Configuration saved in /home/csgrad/smaranas/STDA/checkpoint-833/config.json
# Model weights saved in /home/csgrad/smaranas/STDA/checkpoint-833/pytorch_model.bin
# /home/csgrad/smaranas/.local/lib/python3.6/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set  don't have a corresponding argument in `RobertaForSequenceClassification.forward` and have been ignored: Unnamed: 0, text. If Unnamed: 0, text are not expected by `RobertaForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 2372
#   Batch size = 8
# Saving model checkpoint to /home/csgrad/smaranas/STDA/checkpoint-882
# Configuration saved in /home/csgrad/smaranas/STDA/checkpoint-882/config.json
# Model weights saved in /home/csgrad/smaranas/STDA/checkpoint-882/pytorch_model.bin
# /home/csgrad/smaranas/.local/lib/python3.6/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set  don't have a corresponding argument in `RobertaForSequenceClassification.forward` and have been ignored: Unnamed: 0, text. If Unnamed: 0, text are not expected by `RobertaForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 2372
#   Batch size = 8
# Saving model checkpoint to /home/csgrad/smaranas/STDA/checkpoint-931
# Configuration saved in /home/csgrad/smaranas/STDA/checkpoint-931/config.json
# Model weights saved in /home/csgrad/smaranas/STDA/checkpoint-931/pytorch_model.bin
# /home/csgrad/smaranas/.local/lib/python3.6/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set  don't have a corresponding argument in `RobertaForSequenceClassification.forward` and have been ignored: Unnamed: 0, text. If Unnamed: 0, text are not expected by `RobertaForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 2372
#   Batch size = 8
# Saving model checkpoint to /home/csgrad/smaranas/STDA/checkpoint-980
# Configuration saved in /home/csgrad/smaranas/STDA/checkpoint-980/config.json
# Model weights saved in /home/csgrad/smaranas/STDA/checkpoint-980/pytorch_model.bin
# /home/csgrad/smaranas/.local/lib/python3.6/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set  don't have a corresponding argument in `RobertaForSequenceClassification.forward` and have been ignored: Unnamed: 0, text. If Unnamed: 0, text are not expected by `RobertaForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 2372
#   Batch size = 8
# Saving model checkpoint to /home/csgrad/smaranas/STDA/checkpoint-1029
# Configuration saved in /home/csgrad/smaranas/STDA/checkpoint-1029/config.json
# Model weights saved in /home/csgrad/smaranas/STDA/checkpoint-1029/pytorch_model.bin
# /home/csgrad/smaranas/.local/lib/python3.6/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set  don't have a corresponding argument in `RobertaForSequenceClassification.forward` and have been ignored: Unnamed: 0, text. If Unnamed: 0, text are not expected by `RobertaForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 2372
#   Batch size = 8
# Saving model checkpoint to /home/csgrad/smaranas/STDA/checkpoint-1078
# Configuration saved in /home/csgrad/smaranas/STDA/checkpoint-1078/config.json
# Model weights saved in /home/csgrad/smaranas/STDA/checkpoint-1078/pytorch_model.bin
# /home/csgrad/smaranas/.local/lib/python3.6/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set  don't have a corresponding argument in `RobertaForSequenceClassification.forward` and have been ignored: Unnamed: 0, text. If Unnamed: 0, text are not expected by `RobertaForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 2372
#   Batch size = 8
# Saving model checkpoint to /home/csgrad/smaranas/STDA/checkpoint-1127
# Configuration saved in /home/csgrad/smaranas/STDA/checkpoint-1127/config.json
# Model weights saved in /home/csgrad/smaranas/STDA/checkpoint-1127/pytorch_model.bin
# /home/csgrad/smaranas/.local/lib/python3.6/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set  don't have a corresponding argument in `RobertaForSequenceClassification.forward` and have been ignored: Unnamed: 0, text. If Unnamed: 0, text are not expected by `RobertaForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 2372
#   Batch size = 8
# Saving model checkpoint to /home/csgrad/smaranas/STDA/checkpoint-1176
# Configuration saved in /home/csgrad/smaranas/STDA/checkpoint-1176/config.json
# Model weights saved in /home/csgrad/smaranas/STDA/checkpoint-1176/pytorch_model.bin
# /home/csgrad/smaranas/.local/lib/python3.6/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set  don't have a corresponding argument in `RobertaForSequenceClassification.forward` and have been ignored: Unnamed: 0, text. If Unnamed: 0, text are not expected by `RobertaForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 2372
#   Batch size = 8
# Saving model checkpoint to /home/csgrad/smaranas/STDA/checkpoint-1225
# Configuration saved in /home/csgrad/smaranas/STDA/checkpoint-1225/config.json
# Model weights saved in /home/csgrad/smaranas/STDA/checkpoint-1225/pytorch_model.bin
# /home/csgrad/smaranas/.local/lib/python3.6/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set  don't have a corresponding argument in `RobertaForSequenceClassification.forward` and have been ignored: Unnamed: 0, text. If Unnamed: 0, text are not expected by `RobertaForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 2372
#   Batch size = 8
# Saving model checkpoint to /home/csgrad/smaranas/STDA/checkpoint-1274
# Configuration saved in /home/csgrad/smaranas/STDA/checkpoint-1274/config.json
# Model weights saved in /home/csgrad/smaranas/STDA/checkpoint-1274/pytorch_model.bin
# /home/csgrad/smaranas/.local/lib/python3.6/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set  don't have a corresponding argument in `RobertaForSequenceClassification.forward` and have been ignored: Unnamed: 0, text. If Unnamed: 0, text are not expected by `RobertaForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 2372
#   Batch size = 8
# Saving model checkpoint to /home/csgrad/smaranas/STDA/checkpoint-1323
# Configuration saved in /home/csgrad/smaranas/STDA/checkpoint-1323/config.json
# Model weights saved in /home/csgrad/smaranas/STDA/checkpoint-1323/pytorch_model.bin
# /home/csgrad/smaranas/.local/lib/python3.6/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set  don't have a corresponding argument in `RobertaForSequenceClassification.forward` and have been ignored: Unnamed: 0, text. If Unnamed: 0, text are not expected by `RobertaForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 2372
#   Batch size = 8
# Saving model checkpoint to /home/csgrad/smaranas/STDA/checkpoint-1372
# Configuration saved in /home/csgrad/smaranas/STDA/checkpoint-1372/config.json
# Model weights saved in /home/csgrad/smaranas/STDA/checkpoint-1372/pytorch_model.bin
# /home/csgrad/smaranas/.local/lib/python3.6/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set  don't have a corresponding argument in `RobertaForSequenceClassification.forward` and have been ignored: Unnamed: 0, text. If Unnamed: 0, text are not expected by `RobertaForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 2372
#   Batch size = 8
# Saving model checkpoint to /home/csgrad/smaranas/STDA/checkpoint-1421
# Configuration saved in /home/csgrad/smaranas/STDA/checkpoint-1421/config.json
# Model weights saved in /home/csgrad/smaranas/STDA/checkpoint-1421/pytorch_model.bin
# /home/csgrad/smaranas/.local/lib/python3.6/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set  don't have a corresponding argument in `RobertaForSequenceClassification.forward` and have been ignored: Unnamed: 0, text. If Unnamed: 0, text are not expected by `RobertaForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 2372
#   Batch size = 8
# Saving model checkpoint to /home/csgrad/smaranas/STDA/checkpoint-1470
# Configuration saved in /home/csgrad/smaranas/STDA/checkpoint-1470/config.json
# Model weights saved in /home/csgrad/smaranas/STDA/checkpoint-1470/pytorch_model.bin
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
#
#
# Loading best model from /home/csgrad/smaranas/STDA/checkpoint-343 (score: 0.4244976341724396).
# TrainOutput(global_step=1470, training_loss=0.2964328759052113, metrics={'train_runtime': 8229.8012, 'train_samples_per_second': 34.579, 'train_steps_per_second': 0.179, 'total_flos': 7.486167035781734e+16, 'train_loss': 0.2964328759052113, 'epoch': 29.99})

# %%
trainer.evaluate()
# Out:
# The following columns in the evaluation set  don't have a corresponding argument in `RobertaForSequenceClassification.forward` and have been ignored: Unnamed: 0, text. If Unnamed: 0, text are not expected by `RobertaForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 2372
#   Batch size = 8
# /home/csgrad/smaranas/.local/lib/python3.6/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
#     <div>
#
#       <progress value='75' max='75' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [75/75 00:14]
#     </div>
# {'eval_loss': 0.4244978427886963,
#  'eval_accuracy': 0.8440134907251264,
#  'eval_f1': 0.846219595149542,
#  'eval_precision': 0.8505508847831962,
#  'eval_recall': 0.8470660678717997,
#  'eval_runtime': 14.7225,
#  'eval_samples_per_second': 161.114,
#  'eval_steps_per_second': 5.094,
#  'epoch': 29.99}

# %%
recall = [0.296571,
0.655857,
0.767222,
0.789228,
0.803956,
0.806804,
0.847066,
0.839569,
0.828028,
0.837568,
0.819587,
0.854334,
0.858446,
0.857630,
0.871951,
0.851720,
0.863486,
0.865399,
0.841621,
0.874128,
0.858510,
0.871986,
0.874497,
0.863914,
0.877331,
0.876417,
0.873857,
0.866245,
0.880618,
0.881229,]

precision = [0.356885,
0.648720,
0.776460,
0.795460,
0.811777,
0.832636,
0.850551,
0.849426,
0.847920,
0.858325,
0.842292,
0.858707,
0.870259,
0.868779,
0.874690,
0.858540,
0.871680,
0.868850,
0.867023,
0.878355,
0.870065,
0.881134,
0.881235,
0.871396,
0.881466,
0.883078,
0.879808,
0.876884,
0.884091,
0.884335,]

f1 = [0.220402,
0.627497,
0.764098,
0.786528,
0.801658,
0.799916,
0.846220,
0.839441,
0.822398,
0.832039,
0.815709,
0.853485,
0.858829,
0.857112,
0.871853,
0.849879,
0.862103,
0.865082,
0.841903,
0.873340,
0.857825,
0.872748,
0.875060,
0.861993,
0.875928,
0.875731,
0.872247,
0.864369,
0.879786,
0.880658,]

accuracy = [0.287099,
0.654722,
0.765599,
0.787099,
0.801855,
0.806071,
0.844013,
0.837268,
0.824621,
0.833474,
0.816189,
0.852867,
0.854975,
0.853710,
0.869309,
0.849494,
0.859612,
0.863406,
0.837690,
0.870152,
0.856239,
0.868465,
0.872681,
0.859612,
0.873103,
0.872260,
0.869309,
0.861720,
0.876476,
0.877319,]


validation_loss = [2.186842,
1.166198,
0.696295,
0.593255,
0.536342,
0.528933,
0.424498,
0.457632,
0.537550,
0.506270,
0.659687,
0.551709,
0.559344,
0.558760,
0.522413,
0.664865,
0.696518,
0.643400,
0.826523,
0.672140,
0.749824,
0.770781,
0.728389,
0.822151,
0.762331,
0.789314,
0.804961,
0.895249,
0.787886,
0.781676,]

training_loss = [2.289800,
1.355000,
0.820100,
0.615300,
0.520700,
0.468900,
0.407500,
0.387600,
0.218500,
0.209700,
0.227600,
0.123300,
0.090500,
0.134500,
0.078300,
0.051700,
0.032300,
0.025500,
0.036700,
0.024200,
0.023400,
0.018200,
0.009500,
0.006300,
0.012900,
0.004200,
0.002100,
0.001300,
0.001200,
0.001300,]

# %%
epoch = range(1,31)

# %%
import matplolib.pyplot as plt

plt.plot(epoch, training_loss, label='training_loss')
plt.plot(epoch, validation_loss, label='validation_loss')
plt.plot(epoch, accuracy, label='accuracy')
plt.plot(epoch, f1, label='f1')
plt.plot(epoch, precision, label='precision')
plt.plot(epoch, recall, label='recall')

plt.xlabel('epoch')
plt.legend()
plt.title('training stats')
plt.savefig('training_stats.png')
